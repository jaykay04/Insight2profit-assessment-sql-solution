# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from fake_useragent import UserAgent

ua = UserAgent()
userAgent = ua.random
headers = {"user-agent": userAgent}

base_url = "https://www.espn.com/college-football/stats/player/_/view/offense/stat/passing/season/2024/seasontype/2"
start = 1
all_data_rows = []
table_headers = []

while True:
    url = f"{base_url}/table/{start}"
    response = requests.get(url, headers = headers)
    soup = BeautifulSoup(response.text, "html.parser")

    espn_table = soup.find("div", class_="ResponsiveTable ResponsiveTable--fixed-left mt4 Table2__title--remove-capitalization")
    if not espn_table:
        break  # No more tables found = end of data

    if start == 1:  # Only fetch headers once
        table_headers = [header.text.strip() for header in espn_table.find_all("th")]

    name_rows = []
    stat_rows = []

    # Player names
    name_tbody = espn_table.find_all("tbody")[0]
    for row in name_tbody.find_all("tr"):
        fixed = [td.text.strip() for td in row.find_all("td")]
        name_rows.append(fixed)

    # Stats
    stat_tbody = espn_table.find_all("tbody")[1]
    for row in stat_tbody.find_all("tr"):
        stats = [td.text.strip() for td in row.find_all("td")]
        stat_rows.append(stats)

    # Combine rows
    for name, stats in zip(name_rows, stat_rows):
        all_data_rows.append(name + stats)

    print(f"Fetched {len(name_rows)} records from start={start}")

    if len(name_rows) == 0:  # No more data
        break

    start += 50  # ESPN paginates in sets of 50

# Final DataFrame
espn_df = pd.DataFrame(all_data_rows, columns=table_headers)
espn_df
# print(f"Total records fetched: {len(espn_df)}")
# Out:
# Fetched 50 records from start=1
# Fetched 50 records from start=51
# Fetched 50 records from start=101
# Fetched 50 records from start=151
# Fetched 50 records from start=201
# Fetched 50 records from start=251
# Fetched 50 records from start=301
# Fetched 50 records from start=351
# Fetched 50 records from start=401
# Fetched 50 records from start=451
# Fetched 50 records from start=501
# Fetched 50 records from start=551
# Fetched 50 records from start=601
# Fetched 50 records from start=651
# Fetched 50 records from start=701
# Fetched 50 records from start=751
# Fetched 50 records from start=801
# Fetched 50 records from start=851
# Fetched 50 records from start=901
# Fetched 50 records from start=951
# Fetched 50 records from start=1001
# Fetched 50 records from start=1051
# Fetched 50 records from start=1101
# Fetched 50 records from start=1151
# Fetched 50 records from start=1201
# Fetched 50 records from start=1251
# Fetched 50 records from start=1301
# Fetched 50 records from start=1351
# Fetched 50 records from start=1401
# Fetched 50 records from start=1451
# Fetched 50 records from start=1501
# Fetched 50 records from start=1551
# Fetched 50 records from start=1601
# Fetched 50 records from start=1651
# Fetched 50 records from start=1701
# Fetched 50 records from start=1751
# Fetched 50 records from start=1801
# Fetched 50 records from start=1851
# Fetched 50 records from start=1901
# Fetched 50 records from start=1951
# Fetched 50 records from start=2001
# Fetched 50 records from start=2051
# Fetched 50 records from start=2101
# Fetched 50 records from start=2151
# Fetched 50 records from start=2201
# Fetched 50 records from start=2251
# Fetched 50 records from start=2301
# Fetched 50 records from start=2351
# Fetched 50 records from start=2401
# Fetched 50 records from start=2451
# Fetched 50 records from start=2501
# Fetched 50 records from start=2551
# Fetched 50 records from start=2601
# Fetched 50 records from start=2651
# Fetched 50 records from start=2701
# Fetched 50 records from start=2751
# Fetched 50 records from start=2801
# Fetched 50 records from start=2851
# Fetched 50 records from start=2901
# Fetched 50 records from start=2951
# Fetched 50 records from start=3001
# Fetched 50 records from start=3051
# Fetched 50 records from start=3101
# Fetched 50 records from start=3151
# Fetched 50 records from start=3201
# Fetched 50 records from start=3251
# Fetched 50 records from start=3301
# Fetched 50 records from start=3351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 17
#      15 while True:
#      16     url = f"{base_url}/table/{start}"
# ---> 17     response = requests.get(url, headers = headers)
#      18     soup = BeautifulSoup(response.text, "html.parser")
#      20     espn_table = soup.find("div", class_="ResponsiveTable ResponsiveTable--fixed-left mt4 Table2__title--remove-capitalization")
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~\anaconda3\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\anaconda3\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     825     return
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#     830         break
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:758, in HTTPResponse._update_chunk_length(self)
#     756 if self.chunk_left is not None:
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#     760 try:
#
# File ~\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
